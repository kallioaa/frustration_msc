# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().resolve().parent))

# %%
from experiments.run_experiment import (
    TrainingConfig,
    EvaluateConfig,
)
from experiments.run_sweep import run_sweep, plot_sweep_training_curves
from environments.fronzenlake import FrozenLakeConfig, get_frozenlake_env
from environments.cliffwalking import CliffWalkingConfig, get_cliffwalking_env
from agents.sarsa_td0 import SarsaTD0Agent, SarsaTD0Config
from agents.sarsa_td0_variant import (
    SarsaTD0VariantAgent,
    SarsaTD0VariantConfig,
)   
from metrics.learning_mertrics import total_reward_per_episode, episode_won
from metrics.frustration_metrics import (
    total_td_error_per_episode,
    frustration_rate_per_episode,
    tail_frustration_per_episode,
    cvar_tail_frustration_per_episode,
)

# %%
env_config = CliffWalkingConfig()

# %%
# env_config = FrozenLakeConfig(map_name="4x4", is_slippery=False)
env_config = FrozenLakeConfig(
    map_name="4x4",
    is_slippery=True,
    reward_schedule=(1.0, -1.0, -0.1),
)

# %%
# sarsa_td0 agent
agent_factory = SarsaTD0Agent

sarsa_td0_config = SarsaTD0Config(
    alpha=0.05,
    gamma=0.99,
    epsilon=0.3,
    reward_metrics={
        "total_reward_per_episode": total_reward_per_episode,
        "episode_won": episode_won,
    },
    td_error_metrics={
        "total_td_error_per_episode": total_td_error_per_episode,
        "frustration_rate_per_episode": frustration_rate_per_episode,
        "tail_frustration_per_episode": lambda td: tail_frustration_per_episode(
            td, percentile=0.90
        ),
        "cvar_tail_frustration_per_episode": lambda td: cvar_tail_frustration_per_episode(
            td, percentile=0.90
        ),
    },
)

# %%
# sarsa_td0 agent
agent_factory = SarsaTD0LowerExpectationsAgent

sarsa_td0_config = SarsaTD0LowerExpectationsConfig(
    alpha=0.05,
    gamma=0.99,
    lower_expectations=0.0,
    epsilon=0.3,
    reward_metrics={
        "total_reward_per_episode": total_reward_per_episode,
        "episode_won": episode_won,
    },
    td_error_metrics={
        "total_td_error_per_episode": total_td_error_per_episode,
        "frustration_rate_per_episode": frustration_rate_per_episode,
        "tail_frustration_per_episode": lambda td: tail_frustration_per_episode(
            td, percentile=0.90
        ),
        "cvar_tail_frustration_per_episode": lambda td: cvar_tail_frustration_per_episode(
            td, percentile=0.90
        ),
    },
)

# %%
# sarsa_td0 agent
agent_factory = SarsaTD0VariantAgent

sarsa_td0_config = SarsaTD0VariantConfig(
    alpha_positive=0.2,
    alpha_negative=0.2,
    gamma=0.99,
    epsilon=0.3,
    reward_metrics={
        "total_reward_per_episode": total_reward_per_episode,
        "episode_won": episode_won,
    },
    td_error_metrics={
        "total_td_error_per_episode": total_td_error_per_episode,
        "frustration_rate_per_episode": frustration_rate_per_episode,
        "tail_frustration_per_episode": lambda td: tail_frustration_per_episode(
            td, percentile=0.90
        ),
        "cvar_tail_frustration_per_episode": lambda td: cvar_tail_frustration_per_episode(
            td, percentile=0.90
        ),
    },
)

# %%
base_train = TrainingConfig(
    name="sarsa_frozenlake",
    num_train_episodes=12000,
    env_kwargs={"config": env_config},
    agent_kwargs={"config": sarsa_td0_config},
)

base_eval = EvaluateConfig(
    name="sarsa_frozenlake",
    num_eval_episodes=2000,
    env_kwargs={"config": env_config},
)

# %%
base_train = TrainingConfig(
    name="sarsa_cliffwalking",
    num_train_episodes=100,
    env_kwargs={"config": env_config},
    agent_kwargs={"config": sarsa_td0_config},
)

base_eval = EvaluateConfig(
    name="sarsa_cliffwalking",
    num_eval_episodes=10,
    env_kwargs={"config": env_config},
)

# %%
sweep = {
    "agent_kwargs": [
        {"alpha_positive": ap, "alpha_negative": an, "seed": 2}
        for ap, an in [
            (0.05, 0.05),
            (0.1, 0.1),
            (0.2, 0.2)
        ]
    ],
}

# %%
results = run_sweep(
    base_training=base_train,
    base_evaluation=base_eval,
    sweep=sweep,
    env_factory=get_cliffwalking_env,
    agent_factory=agent_factory,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results = run_sweep(
#       2     base_training=base_train,
#       3     base_evaluation=base_eval,
#       4     sweep=sweep,
#       5     env_factory=get_cliffwalking_env,
#       6     agent_factory=agent_factory,
#       7 )
#
# File ~/frustration_msc/src/experiments/run_sweep.py:78, in run_sweep(base_training, base_evaluation, sweep, env_factory, agent_factory)
#      73     evaluation_config = EvaluateConfig(**evaluation_dict)
#      75     agent, training_metrics = run_training(
#      76         training_config, env_factory=env_factory, agent_factory=agent_factory
#      77     )
# ---> 78     eval_metrics = run_evaluation(
#      79         evaluation_config, env_factory=env_factory, agent=agent
#      80     )
#      82     results.append(
#      83         {
#      84             "params": override,
#    (...)
#      87         }
#      88     )
#      90 return results
#
# File ~/frustration_msc/src/experiments/run_experiment.py:77, in run_evaluation(config, env_factory, agent)
#      74 env_kwargs = config.env_kwargs or {}
#      75 env = env_factory(**env_kwargs)
# ---> 77 eval_metrics = evaluator(
#      78     env, agent, num_episodes=config.num_eval_episodes, seed=config.seed
#      79 )
#      81 config_dict = asdict(config)
#      82 evaluation_metrics: Dict[str, Any] = {
#      83     "timestamp": _timestamp(),
#      84     "config": config_dict,
#      85     "eval": eval_metrics,
#      86 }
#
# File ~/frustration_msc/src/evaluation/evaluator.py:20, in evaluator(env, agent, num_episodes, seed)
#      17 total_reward = 0.0
#      19 while not done:
# ---> 20     action = agent.act(state)
#      21     state, reward, terminated, truncated, _ = env.step(action)
#      22     done = terminated or truncated
#
# File ~/frustration_msc/src/agents/sarsa_td0_variant.py:107, in SarsaTD0VariantAgent.act(self, state)
#     105 if self.q_table is None:
#     106     raise RuntimeError("Q-table is not initialized. Call train() first.")
# --> 107 return int(np.argmax(self.q_table[state]))
#
# File ~/frustration_msc/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:1314, in argmax(a, axis, out, keepdims)
#    1223 """
#    1224 Returns the indices of the maximum values along an axis.
#    1225
#    (...)
#    1311 (2, 1, 4)
#    1312 """
#    1313 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1314 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~/frustration_msc/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      51     return _wrapit(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#      63     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
plot_sweep_training_curves(results, window_size=1000)
